# %% [markdown]
# # Punctuation
# - Punctuation is the set of symbols (.,!?:;"' etc.) used in writing to organize text, indicate pauses, express emotions, and clarify meaning.
#
# - Punctuation refers to the symbols used in writing to organize sentences, clarify meaning, indicate pauses, and express emotions

# %% [markdown]
# # Common Punctuation Marks

# %% [markdown]
# | Symbol | Name               | Purpose                              |
# | ------ | ------------------ | ------------------------------------ |
# | .      | Period (Full Stop) | Ends a sentence                      |
# | ,      | Comma              | Indicates a short pause              |
# | ?      | Question Mark      | Ends a question                      |
# | !      | Exclamation Mark   | Shows excitement or strong emotion   |
# | :      | Colon              | Introduces a list or explanation     |
# | ;      | Semicolon          | Connects closely related sentences   |
# | " "    | Quotation Marks    | Shows direct speech or quotations    |
# | '      | Apostrophe         | Indicates possession or contractions |
# | ( )    | Parentheses        | Adds extra information               |

# %% [markdown]
# # Method 1: Using string.punctuation

# %%
import string
text = "Hello!!! How are you?"

clean_text = text.translate(str.maketrans('','',string.punctuation))

print(clean_text)
# Out:
# Hello How are you

# %%
import string

filter_tokens = ["hello!", "AI,", "world?"]

# %%
filter_tokens
# Out:
# ['hello!', 'AI,', 'world?']

# %%
for word in filter_tokens:
    print(word)
# Out:
# hello!
# AI,
# world?

# %%
for word in filter_tokens:
    for char in word:
        print(char)
# Out:
# h
# e
# l
# l
# o
# !
# A
# I
# ,
# w
# o
# r
# l
# d
# ?

# %%
import string

filter_tokens = ["hello!", "AI,", "world?"]

["".join(char for char in word if char not in string.punctuation)
 for word in filter_tokens]
# Out:
# ['hello', 'AI', 'world']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
new_list = []

for word in filter_tokens:
    
    new_word = ""

    for char in word:

        if char not in string.punctuation:
            new_word = new_word + char

    new_list.append(new_word)

print(new_list)
# Out:
# ['hello', 'AI', 'world']

# %% [markdown]
# # Method 2: Using Regular Expressions (Regex)

# %%
import re

text = "Hello!!! How are you?"
lean_text = re.sub(r'[^\w\s]', '', text)
print(clean_text)
# Out:
# Hello How are you

# %% [markdown]
# # Why Remove Punctuation?
# - Reduces noise in text data
# - Makes text processing easier
# - Improves traditional NLP tasks like:
# - Text Classification
# - Sentiment Analysis
# - Topic Modeling

# %% [markdown]
# ![image.png](attachment:1e1c4075-8beb-41dd-ac54-6959352a3a83.png)

# %% [markdown]
# ![image.png](attachment:d47f4e45-9210-4a71-a3a4-fb7fb60feff0.png)
